# %%
import pandas

# %%
db = pandas.read_csv("DipakMarks.txt")

# %%
db
# Out:
#    Hrs  Marks
# 0    2     20
# 1    5     50
# 2    6     60
# 3    1     10
# 4    8     80

# %%
y = db['Marks']

# %%
y
# Out:
# 0    20
# 1    50
# 2    60
# 3    10
# 4    80
# Name: Marks, dtype: int64

# %%
x = x.values.reshape(-1,1)

# %%
x
# Out:
# array([[2],
#        [5],
#        [6],
#        [1],
#        [8]])

# %%
from sklearn.linear_model import LinearRegression

# %%
#Model create
model = LinearRegression()

# %%
#Model Trained
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# model.predict(x)

# %%
#model Predict the output
model.predict([[9]])
# Out:
# array([90.])

# %%
import joblib

# %%
joblib.dump(model,"MarksPredict")
# Out:
# ['MarksPredict']
